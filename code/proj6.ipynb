# %% [markdown]
# # [Deep Learning](https://www.cc.gatech.edu/~hays/compvision/proj6/)

# %% [markdown]
# ## Setup

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import random
import torch.nn as nn
import torch.optim as optim
import os.path as osp
import matplotlib.pyplot as plt
from utils import *
import student_code as sc
from torchvision.models import alexnet

data_path = osp.join('../data', '15SceneData')
num_classes = 15

# If you have a good Nvidia GPU with an appropriate environment, 
# try setting the use_GPU flag to True (the environment provided does
# not support GPUs and we will not provide any support for GPU
# computation in this project). Please note that 
# we will evaluate your implementations only using CPU mode so even if
# you use a GPU, make sure your code runs in the CPU mode with the
# environment we provided. 
use_GPU = False
if use_GPU:
    from utils_gpu import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# To train a network in PyTorch, we need 4 components:
# 1. **Dataset** - an object which can load the data and labels given an index.
# 2. **Model** - an object that contains the network architecture definition.
# 3. **Loss function** - a function that measures how far the network output is from the ground truth label.
# 4. **Optimizer** - an object that optimizes the network parameters to reduce the loss value.

# %% [markdown]
# This project has two main parts. In Part 1, you will train a deep network from scratch. In Part 2, you will "fine-tune" a trained network.

# %% [markdown]
# ## Part 0. Warm up! Training a Deep Network from Scratch

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# You do not need to code anything for this part. You will simply run the code we provided, but we want you to report the result you got. This section will also familiarize you with the steps of training a deep network from scratch.

# %%
# Training parameters.
input_size = (64, 64)
RGB = False  
base_lr = 0.75e-1  # may try a smaller lr if not using batch norm
weight_decay = 5e-4
momentum = 0.9

# %% [markdown]
# We will first create our datasets, by calling the create_datasets function from student_code. This function returns a separate dataset loader for each split of the dataset (training and testing/validation). Each dataloader is used to load the datasets after appling some pre-processing transforms. In Part 1, you will be asked to add a few more pre-processing transforms to the dataloaders by modifying this function.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now we will create our network model using the SimpleNet class from student_code. The implementation provided in the SimpleNet class gives you a basic network. In Part 1, you will be asked to add a few more layers to this network.

# %%
# Create the network model.
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): MaxPool2d(kernel_size=7, stride=7, padding=0, dilation=1, ceil_mode=False)
#     (2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(10, 25, kernel_size=(6, 6), stride=(1, 1), bias=False)
#     (5): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): ReLU()
#     (8): Dropout(p=0.3)
#   )
#   (classifier): Conv2d(25, 15, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# Next we will create the loss function and the optimizer.

# %%
# Create the loss function.
# see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
loss_function = nn.CrossEntropyLoss()

# %%
# Create the optimizer and a learning rate scheduler
optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
# Currently a simple step scheduler.
# See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
# and how to use them
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

# %% [markdown]
# Finally we are ready to train our network! We will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# train the network!
params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))

# %% [markdown]
# Expect this code to take around 5 minutes on CPU or 3 minutes on GPU. Now you are ready to actually modify the functions we used to train our model. Before you move on, make sure to record the accuracy of your network from Part 0, and report it in your write up.

# %% [markdown]
# ## Part 1: Modifying the Dataloaders and the Simple Network create_datasets

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Now you will modify the create_datasets function from student_code. You will add random left-right mirroring and normalization to the transformations applied to the training dataset. You will also add normalization to the transformations applied to the testing dataset.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now you will modify SimpleNet by adding droppout, batch normalization, and additional convolution/maxpool/relu layers. You should achieve an accuracy of at least **50%**. Make sure your network passes this threshold--it is required for full credit on this section!
#
# You can also use the following two blocks to determine the stucture of your network.

# %%
# create the network model
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=7, stride=7, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): Dropout(p=0.5)
#     (5): Conv2d(32, 128, kernel_size=(6, 6), stride=(1, 1), bias=False)
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#     (9): Dropout(p=0.5)
#   )
#   (classifier): Linear(in_features=128, out_features=15, bias=True)
# )

# %%
# Use this block to determine the kernel size of the conv2d layer in the classifier
# first, set the kernel size of that conv2d layer to 1, and run this block
# then, use that size of input to the classifier printed by this block to
# go back and update the kernel size of the conv2d layer in the classifier
# Finally, run this block again and verify that the network output size is a scalar
# Don't forget to re-run the block above every time you update the SimpleNet class!
from torch.autograd import Variable
data, _ = train_dataset[0]
s = data.size()
data = Variable(data.view(1, *s))
if use_GPU:
    data = data.cuda()
out = model(data)
print('Network output size is ', out.size())
# Out:
# Network output size is  torch.Size([15])

# %% [markdown]
# Next we will create the loss function and the optimizer. You do not have to modify the custom_part1_trainer in student_code if you use the same loss_function, optimizer, scheduler and parameters (n_epoch, batch_size etc.) as provided in this notebook to hit the required threshold of 50% accuracy. If you changed any of these values, it is important that you modify this function in student_code since we will not be using the notebook you submit to evaluate.

# %%
# Set up the trainer. You can modify custom_part1_trainer in
# student_copy.py if you want to try different learning settings.
custom_part1_trainer = sc.custom_part1_trainer(model)

if custom_part1_trainer is None:
    # Create the loss function.
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Create the optimizer and a learning rate scheduler.
    optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
    # Currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

    params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
    
else:
    if 'loss_function' in custom_part1_trainer:
        loss_function = custom_part1_trainer['loss_function']
    if 'optimizer' in custom_part1_trainer:
        optimizer = custom_part1_trainer['optimizer']
    if 'lr_scheduler' in custom_part1_trainer:
        lr_scheduler = custom_part1_trainer['lr_scheduler']
    if 'params' in custom_part1_trainer:
        params = custom_part1_trainer['params']

# %% [markdown]
# We are ready to train our network! As before, we will start a local server to see the training progress of our network (if you server is already running, you should not start another one). Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part1
# batch_size: 50
# checkpoint_file: None
# print_freq: 100
# experiment: part1
# do_val: True
# shuffle: True
# num_workers: 8
# resume_optim: True
# val_freq: 1
# n_epochs: 100
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.699, top-1 accuracy 8.000, top-5 accuracy 34.000
# train part1: loss 2.679552
# val part1: batch 0/59, loss 4.874, top-1 accuracy 0.000, top-5 accuracy 2.000
# val part1: loss 2.962182
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.468, top-1 accuracy 16.000, top-5 accuracy 62.000
# train part1: loss 2.360851
# val part1: batch 0/59, loss 2.288, top-1 accuracy 32.000, top-5 accuracy 66.000
# val part1: loss 2.117693
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.167, top-1 accuracy 40.000, top-5 accuracy 72.000
# train part1: loss 2.131426
# val part1: batch 0/59, loss 2.256, top-1 accuracy 24.000, top-5 accuracy 64.000
# val part1: loss 2.137438
# Checkpoint saved
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 1.915, top-1 accuracy 36.000, top-5 accuracy 76.000
# train part1: loss 1.997516
# val part1: batch 0/59, loss 2.231, top-1 accuracy 28.000, top-5 accuracy 70.000
# val part1: loss 1.858935
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 2.019, top-1 accuracy 36.000, top-5 accuracy 70.000
# train part1: loss 1.981753
# val part1: batch 0/59, loss 2.581, top-1 accuracy 4.000, top-5 accuracy 62.000
# val part1: loss 1.817324
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 1.808, top-1 accuracy 40.000, top-5 accuracy 78.000
# train part1: loss 1.937952
# val part1: batch 0/59, loss 2.256, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.937411
# Checkpoint saved
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 1.508, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.906743
# val part1: batch 0/59, loss 2.352, top-1 accuracy 14.000, top-5 accuracy 60.000
# val part1: loss 1.811147
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 2.023, top-1 accuracy 34.000, top-5 accuracy 80.000
# train part1: loss 1.878431
# val part1: batch 0/59, loss 1.935, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.818406
# Checkpoint saved
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 1.726, top-1 accuracy 38.000, top-5 accuracy 84.000
# train part1: loss 1.867457
# val part1: batch 0/59, loss 1.670, top-1 accuracy 60.000, top-5 accuracy 94.000
# val part1: loss 1.783438
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 1.694, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.821310
# val part1: batch 0/59, loss 2.642, top-1 accuracy 4.000, top-5 accuracy 50.000
# val part1: loss 1.731130
# Checkpoint saved
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 2.121, top-1 accuracy 26.000, top-5 accuracy 80.000
# train part1: loss 1.813254
# val part1: batch 0/59, loss 2.267, top-1 accuracy 22.000, top-5 accuracy 70.000
# val part1: loss 1.714958
# Checkpoint saved
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.892, top-1 accuracy 40.000, top-5 accuracy 74.000
# train part1: loss 1.800049
# val part1: batch 0/59, loss 1.947, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.705920
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.559, top-1 accuracy 48.000, top-5 accuracy 86.000
# train part1: loss 1.762077
# val part1: batch 0/59, loss 2.299, top-1 accuracy 18.000, top-5 accuracy 62.000
# val part1: loss 1.644757
# Checkpoint saved
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.832, top-1 accuracy 32.000, top-5 accuracy 92.000
# train part1: loss 1.747104
# val part1: batch 0/59, loss 2.276, top-1 accuracy 18.000, top-5 accuracy 72.000
# val part1: loss 1.698637
# Checkpoint saved
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.493, top-1 accuracy 54.000, top-5 accuracy 84.000
# train part1: loss 1.727149
# val part1: batch 0/59, loss 2.030, top-1 accuracy 42.000, top-5 accuracy 72.000
# val part1: loss 1.694708
# Checkpoint saved
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.432, top-1 accuracy 56.000, top-5 accuracy 90.000
# train part1: loss 1.723494
# val part1: batch 0/59, loss 2.182, top-1 accuracy 28.000, top-5 accuracy 70.000
# val part1: loss 1.770967
# Checkpoint saved
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.917, top-1 accuracy 44.000, top-5 accuracy 84.000
# train part1: loss 1.715579
# val part1: batch 0/59, loss 2.220, top-1 accuracy 16.000, top-5 accuracy 74.000
# val part1: loss 1.611612
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.571, top-1 accuracy 50.000, top-5 accuracy 86.000
# train part1: loss 1.677393
# val part1: batch 0/59, loss 2.240, top-1 accuracy 16.000, top-5 accuracy 72.000
# val part1: loss 1.600462
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.565, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.630962
# val part1: batch 0/59, loss 1.813, top-1 accuracy 48.000, top-5 accuracy 82.000
# val part1: loss 1.608467
# Checkpoint saved
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.700, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.615799
# val part1: batch 0/59, loss 1.938, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.586330
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.510, top-1 accuracy 52.000, top-5 accuracy 90.000
# train part1: loss 1.637268
# val part1: batch 0/59, loss 1.799, top-1 accuracy 46.000, top-5 accuracy 78.000
# val part1: loss 1.633962
# Checkpoint saved
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.430, top-1 accuracy 60.000, top-5 accuracy 90.000
# train part1: loss 1.648391
# val part1: batch 0/59, loss 2.215, top-1 accuracy 28.000, top-5 accuracy 68.000
# val part1: loss 1.667879
# Checkpoint saved
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.750, top-1 accuracy 40.000, top-5 accuracy 86.000
# train part1: loss 1.635095
# val part1: batch 0/59, loss 1.925, top-1 accuracy 38.000, top-5 accuracy 72.000
# val part1: loss 1.628978
# Checkpoint saved
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.765, top-1 accuracy 42.000, top-5 accuracy 86.000
# train part1: loss 1.632146
# val part1: batch 0/59, loss 2.283, top-1 accuracy 12.000, top-5 accuracy 72.000
# val part1: loss 1.695143
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 1.850, top-1 accuracy 32.000, top-5 accuracy 90.000
# train part1: loss 1.606372
# val part1: batch 0/59, loss 1.624, top-1 accuracy 48.000, top-5 accuracy 92.000
# val part1: loss 1.560418
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.627, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.584258
# val part1: batch 0/59, loss 1.706, top-1 accuracy 48.000, top-5 accuracy 92.000
# val part1: loss 1.554170
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.198, top-1 accuracy 58.000, top-5 accuracy 98.000
# train part1: loss 1.583236
# val part1: batch 0/59, loss 1.934, top-1 accuracy 34.000, top-5 accuracy 88.000
# val part1: loss 1.551813
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.706, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.630750
# val part1: batch 0/59, loss 2.033, top-1 accuracy 34.000, top-5 accuracy 76.000
# val part1: loss 1.578155
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.534, top-1 accuracy 46.000, top-5 accuracy 92.000
# train part1: loss 1.554737
# val part1: batch 0/59, loss 2.139, top-1 accuracy 26.000, top-5 accuracy 70.000
# val part1: loss 1.527184
# Checkpoint saved
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.460, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.525687
# val part1: batch 0/59, loss 1.770, top-1 accuracy 40.000, top-5 accuracy 86.000
# val part1: loss 1.593696
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.475, top-1 accuracy 44.000, top-5 accuracy 86.000
# train part1: loss 1.566883
# val part1: batch 0/59, loss 1.986, top-1 accuracy 30.000, top-5 accuracy 74.000
# val part1: loss 1.606816
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 1.703, top-1 accuracy 48.000, top-5 accuracy 90.000
# train part1: loss 1.559056
# val part1: batch 0/59, loss 2.718, top-1 accuracy 0.000, top-5 accuracy 46.000
# val part1: loss 1.593053
# Checkpoint saved
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 1.528, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.548201
# val part1: batch 0/59, loss 2.050, top-1 accuracy 28.000, top-5 accuracy 70.000
# val part1: loss 1.573756
# Checkpoint saved
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.522, top-1 accuracy 46.000, top-5 accuracy 92.000
# train part1: loss 1.518666
# val part1: batch 0/59, loss 1.775, top-1 accuracy 42.000, top-5 accuracy 82.000
# val part1: loss 1.572679
# Checkpoint saved
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.409, top-1 accuracy 48.000, top-5 accuracy 90.000
# train part1: loss 1.527163
# val part1: batch 0/59, loss 2.125, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.570054
# Checkpoint saved
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 1.613, top-1 accuracy 48.000, top-5 accuracy 92.000
# train part1: loss 1.518345
# val part1: batch 0/59, loss 2.093, top-1 accuracy 28.000, top-5 accuracy 70.000
# val part1: loss 1.611102
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 1.387, top-1 accuracy 62.000, top-5 accuracy 90.000
# train part1: loss 1.487928
# val part1: batch 0/59, loss 1.821, top-1 accuracy 38.000, top-5 accuracy 78.000
# val part1: loss 1.520885
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 1.704, top-1 accuracy 40.000, top-5 accuracy 90.000
# train part1: loss 1.532494
# val part1: batch 0/59, loss 2.306, top-1 accuracy 10.000, top-5 accuracy 74.000
# val part1: loss 1.577548
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 1.578, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.484784
# val part1: batch 0/59, loss 2.544, top-1 accuracy 4.000, top-5 accuracy 66.000
# val part1: loss 1.605424
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 1.500, top-1 accuracy 58.000, top-5 accuracy 84.000
# train part1: loss 1.491348
# val part1: batch 0/59, loss 1.703, top-1 accuracy 46.000, top-5 accuracy 84.000
# val part1: loss 1.477047
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 1.291, top-1 accuracy 60.000, top-5 accuracy 100.000
# train part1: loss 1.475369
# val part1: batch 0/59, loss 1.777, top-1 accuracy 44.000, top-5 accuracy 80.000
# val part1: loss 1.498309
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 1.253, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.449478
# val part1: batch 0/59, loss 2.084, top-1 accuracy 22.000, top-5 accuracy 68.000
# val part1: loss 1.481030
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 1.265, top-1 accuracy 52.000, top-5 accuracy 96.000
# train part1: loss 1.490255
# val part1: batch 0/59, loss 2.496, top-1 accuracy 8.000, top-5 accuracy 66.000
# val part1: loss 1.507557
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 1.242, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 1.445807
# val part1: batch 0/59, loss 2.357, top-1 accuracy 20.000, top-5 accuracy 64.000
# val part1: loss 1.490834
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 1.560, top-1 accuracy 46.000, top-5 accuracy 88.000
# train part1: loss 1.440376
# val part1: batch 0/59, loss 1.786, top-1 accuracy 40.000, top-5 accuracy 92.000
# val part1: loss 1.506129
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 1.320, top-1 accuracy 54.000, top-5 accuracy 92.000
# train part1: loss 1.438308
# val part1: batch 0/59, loss 1.725, top-1 accuracy 36.000, top-5 accuracy 88.000
# val part1: loss 1.497448
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 1.611, top-1 accuracy 52.000, top-5 accuracy 88.000
# train part1: loss 1.502365
# val part1: batch 0/59, loss 2.319, top-1 accuracy 10.000, top-5 accuracy 74.000
# val part1: loss 1.451537
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 1.578, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.464920
# val part1: batch 0/59, loss 2.039, top-1 accuracy 14.000, top-5 accuracy 78.000
# val part1: loss 1.438045
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 1.249, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.430207
# val part1: batch 0/59, loss 1.817, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.522701
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 1.345, top-1 accuracy 52.000, top-5 accuracy 90.000
# train part1: loss 1.442450
# val part1: batch 0/59, loss 2.056, top-1 accuracy 22.000, top-5 accuracy 72.000
# val part1: loss 1.474347
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 1.335, top-1 accuracy 64.000, top-5 accuracy 90.000
# train part1: loss 1.401111
# val part1: batch 0/59, loss 1.978, top-1 accuracy 20.000, top-5 accuracy 86.000
# val part1: loss 1.508983
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 1.444, top-1 accuracy 46.000, top-5 accuracy 92.000
# train part1: loss 1.448328
# val part1: batch 0/59, loss 2.562, top-1 accuracy 6.000, top-5 accuracy 64.000
# val part1: loss 1.482051
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 1.236, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.457317
# val part1: batch 0/59, loss 1.599, top-1 accuracy 38.000, top-5 accuracy 92.000
# val part1: loss 1.537068
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 1.294, top-1 accuracy 56.000, top-5 accuracy 86.000
# train part1: loss 1.496381
# val part1: batch 0/59, loss 2.629, top-1 accuracy 0.000, top-5 accuracy 52.000
# val part1: loss 1.589801
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 1.655, top-1 accuracy 52.000, top-5 accuracy 82.000
# train part1: loss 1.431730
# val part1: batch 0/59, loss 1.825, top-1 accuracy 34.000, top-5 accuracy 80.000
# val part1: loss 1.470477
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 1.143, top-1 accuracy 58.000, top-5 accuracy 98.000
# train part1: loss 1.346404
# val part1: batch 0/59, loss 2.506, top-1 accuracy 10.000, top-5 accuracy 62.000
# val part1: loss 1.419718
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 1.358, top-1 accuracy 50.000, top-5 accuracy 90.000
# train part1: loss 1.411315
# val part1: batch 0/59, loss 1.795, top-1 accuracy 32.000, top-5 accuracy 84.000
# val part1: loss 1.515294
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 1.638, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.406558
# val part1: batch 0/59, loss 2.267, top-1 accuracy 24.000, top-5 accuracy 72.000
# val part1: loss 1.494433
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 1.765, top-1 accuracy 38.000, top-5 accuracy 88.000
# train part1: loss 1.412936
# val part1: batch 0/59, loss 1.979, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.532160
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 1.530, top-1 accuracy 46.000, top-5 accuracy 94.000
# train part1: loss 1.438067
# val part1: batch 0/59, loss 1.896, top-1 accuracy 26.000, top-5 accuracy 88.000
# val part1: loss 1.426255
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 1.597, top-1 accuracy 52.000, top-5 accuracy 86.000
# train part1: loss 1.323217
# val part1: batch 0/59, loss 1.900, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.373411
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 1.263, top-1 accuracy 60.000, top-5 accuracy 92.000
# train part1: loss 1.251471
# val part1: batch 0/59, loss 1.904, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.368140
# Checkpoint saved
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 0.992, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 1.280781
# val part1: batch 0/59, loss 1.866, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.374603
# Checkpoint saved
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 1.064, top-1 accuracy 68.000, top-5 accuracy 94.000
# train part1: loss 1.256739
# val part1: batch 0/59, loss 1.854, top-1 accuracy 32.000, top-5 accuracy 82.000
# val part1: loss 1.351806
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 1.046, top-1 accuracy 66.000, top-5 accuracy 96.000
# train part1: loss 1.241066
# val part1: batch 0/59, loss 1.880, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.360706
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 1.422, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.228532
# val part1: batch 0/59, loss 1.849, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.360913
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 1.040, top-1 accuracy 66.000, top-5 accuracy 94.000
# train part1: loss 1.214674
# val part1: batch 0/59, loss 1.849, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.346867
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 1.272, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.193272
# val part1: batch 0/59, loss 1.852, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.331865
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 0.984, top-1 accuracy 68.000, top-5 accuracy 94.000
# train part1: loss 1.150452
# val part1: batch 0/59, loss 1.816, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.325962
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 1.094, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.165115
# val part1: batch 0/59, loss 1.858, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.335474
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 1.011, top-1 accuracy 62.000, top-5 accuracy 98.000
# train part1: loss 1.171101
# val part1: batch 0/59, loss 1.848, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.322181
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 1.203, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.175085
# val part1: batch 0/59, loss 1.800, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.330107
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 1.304, top-1 accuracy 64.000, top-5 accuracy 92.000
# train part1: loss 1.174875
# val part1: batch 0/59, loss 1.937, top-1 accuracy 28.000, top-5 accuracy 76.000
# val part1: loss 1.316123
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 1.010, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.163583
# val part1: batch 0/59, loss 1.841, top-1 accuracy 32.000, top-5 accuracy 76.000
# val part1: loss 1.328202
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 1.489, top-1 accuracy 56.000, top-5 accuracy 88.000
# train part1: loss 1.162890
# val part1: batch 0/59, loss 1.785, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.311992
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 1.338, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.149021
# val part1: batch 0/59, loss 1.830, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.312170
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 1.130, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.195336
# val part1: batch 0/59, loss 1.928, top-1 accuracy 26.000, top-5 accuracy 72.000
# val part1: loss 1.317276
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 1.112, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.142320
# val part1: batch 0/59, loss 1.891, top-1 accuracy 28.000, top-5 accuracy 76.000
# val part1: loss 1.307480
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 1.178, top-1 accuracy 58.000, top-5 accuracy 98.000
# train part1: loss 1.151620
# val part1: batch 0/59, loss 1.945, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.308837
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 1.294, top-1 accuracy 62.000, top-5 accuracy 92.000
# train part1: loss 1.127715
# val part1: batch 0/59, loss 1.798, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.308069
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 1.200, top-1 accuracy 62.000, top-5 accuracy 92.000
# train part1: loss 1.154299
# val part1: batch 0/59, loss 1.846, top-1 accuracy 32.000, top-5 accuracy 78.000
# val part1: loss 1.303590
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 1.252, top-1 accuracy 62.000, top-5 accuracy 92.000
# train part1: loss 1.150431
# val part1: batch 0/59, loss 1.757, top-1 accuracy 38.000, top-5 accuracy 82.000
# val part1: loss 1.296133
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 1.093, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.124007
# val part1: batch 0/59, loss 1.788, top-1 accuracy 32.000, top-5 accuracy 78.000
# val part1: loss 1.309364
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 1.212, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 1.142520
# val part1: batch 0/59, loss 1.784, top-1 accuracy 36.000, top-5 accuracy 78.000
# val part1: loss 1.320620
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 1.301, top-1 accuracy 64.000, top-5 accuracy 88.000
# train part1: loss 1.118161
# val part1: batch 0/59, loss 1.874, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.306087
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 1.090, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.073897
# val part1: batch 0/59, loss 1.774, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.288617
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 1.106, top-1 accuracy 66.000, top-5 accuracy 92.000
# train part1: loss 1.084264
# val part1: batch 0/59, loss 1.869, top-1 accuracy 32.000, top-5 accuracy 76.000
# val part1: loss 1.294197
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 1.061, top-1 accuracy 64.000, top-5 accuracy 98.000
# train part1: loss 1.075609
# val part1: batch 0/59, loss 1.816, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.300778
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 1.325, top-1 accuracy 56.000, top-5 accuracy 90.000
# train part1: loss 1.100245
# val part1: batch 0/59, loss 1.799, top-1 accuracy 34.000, top-5 accuracy 78.000
# val part1: loss 1.283607
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 1.351, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.118787
# val part1: batch 0/59, loss 1.872, top-1 accuracy 30.000, top-5 accuracy 76.000
# val part1: loss 1.281873
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 1.301, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.130189
# val part1: batch 0/59, loss 1.825, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.278195
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 1.038, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 1.119738
# val part1: batch 0/59, loss 1.793, top-1 accuracy 34.000, top-5 accuracy 82.000
# val part1: loss 1.290782
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 1.317, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.094567
# val part1: batch 0/59, loss 1.810, top-1 accuracy 32.000, top-5 accuracy 86.000
# val part1: loss 1.278972
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 1.376, top-1 accuracy 48.000, top-5 accuracy 92.000
# train part1: loss 1.125054
# val part1: batch 0/59, loss 1.828, top-1 accuracy 34.000, top-5 accuracy 80.000
# val part1: loss 1.279913
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 0.876, top-1 accuracy 76.000, top-5 accuracy 92.000
# train part1: loss 1.111996
# val part1: batch 0/59, loss 1.731, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.290543
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 1.075, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.127813
# val part1: batch 0/59, loss 1.779, top-1 accuracy 32.000, top-5 accuracy 82.000
# val part1: loss 1.281068
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 1.173, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.085715
# val part1: batch 0/59, loss 1.727, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.281211
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 1.079, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.123005
# val part1: batch 0/59, loss 1.915, top-1 accuracy 28.000, top-5 accuracy 76.000
# val part1: loss 1.291781
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 1.078, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.105377
# val part1: batch 0/59, loss 1.741, top-1 accuracy 36.000, top-5 accuracy 88.000
# val part1: loss 1.286373
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 1.162, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.100745
# val part1: batch 0/59, loss 1.692, top-1 accuracy 42.000, top-5 accuracy 88.000
# val part1: loss 1.282761
# Checkpoint saved
# Best top-1 Accuracy = 57.219

# %% [markdown]
# Make sure you get at least 50% accuracy in this section! If you tried different settings than the ones provided to get 50%, you should modify custom_part1_trainer in student code to return a dictionary with your changed settings.

# %% [markdown]
# ## Part 2. Fine-Tuning a Pre-Trained Network

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Training a network from scratch takes a lof of time. Instead of training from scratch, we can take a pre-trained model and fine tune it for our purposes. This is the goal of Part 2--you will train a pre-trained network, and achieve at least 80% accuracy.

# %%
# training parameters
input_size = (224, 224)
RGB = True
base_lr = 1e-3
weight_decay = 5e-4
momentum = 0.9
backprop_depth = 3

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45611589 0.45611589 0.45611589]
# std =
# [0.24786406 0.24786406 0.24786406]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45549639 0.45549639 0.45549639]
# std =
# [0.24698076 0.24698076 0.24698076]

# %% [markdown]
# Following block loads a pretrained AlexNet.

# %%
# Create the network model.
model = alexnet(pretrained=True)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Now, you modify create_part2_model from student code in order to fine-tune AlexNet. As you can see in the docs (https://github.com/pytorch/vision/blob/master/torchvision/models/alexnet.py) and in the model printout above, AlexNet has 2 parts: 'features', which constists of conv layers that extract feature maps from the image, and 'classifier' which consists of FC layers that classify the features. We want to replace the last Linear layer in model.classifier.

# %%
model = sc.create_part2_model(model, num_classes)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=15, bias=True)
#   )
# )

# %% [markdown]
# Next we will create the loss function and the optimizer. Just as with part 1, if you modify any of the setttings to hit the required accuracy, you must modify custom_part2_trainer function to return a dictionary containing your changes.

# %%
# Set up the trainer. You can modify custom_part2_trainer in
# student_copy.py if you want to try different learning settings.
custom_part2_trainer = sc.custom_part2_trainer(model)

if custom_part2_trainer is None:
    # Create the loss function
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Since we do not want to optimize the whole network, we must extract a list of parameters of interest that will be
    # optimized by the optimizer.
    params_to_optimize = []

    # List of modules in the network
    mods = list(model.features.children()) + list(model.classifier.children())

    # Extract parameters from the last `backprop_depth` modules in the network and collect them in
    # the params_to_optimize list.
    for m in mods[::-1][:backprop_depth]:
        params_to_optimize.extend(list(m.parameters()))

    # Construct the optimizer    
    optimizer = optim.SGD(params=params_to_optimize, lr=base_lr, weight_decay=weight_decay, momentum=momentum)

    # Create a scheduler, currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    
    params = {'n_epochs': 4, 'batch_size': 10, 'experiment': 'part2'} 
    
else:
    if 'loss_function' in custom_part2_trainer:
        loss_function = custom_part2_trainer['loss_function']
    if 'optimizer' in custom_part2_trainer:
        optimizer = custom_part2_trainer['optimizer']
    if 'lr_scheduler' in custom_part2_trainer:
        lr_scheduler = custom_part2_trainer['lr_scheduler']
    if 'params' in custom_part2_trainer:
        params = custom_part2_trainer['params']

# %% [markdown]
# We are ready to fine tune our network! Just like before, we will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 2 on the top left bar where is says Environment (only select Part 2, do not check main or Part 1).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part2
# batch_size: 10
# checkpoint_file: None
# print_freq: 100
# experiment: part2
# do_val: True
# shuffle: True
# num_workers: 8
# resume_optim: True
# val_freq: 1
# n_epochs: 4
# ---------------------------------------
# part2 Epoch 0 / 4
# train part2: batch 0/149, loss 2.994, top-1 accuracy 10.000, top-5 accuracy 20.000
# train part2: batch 100/149, loss 0.352, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.874336
# val part2: batch 0/298, loss 1.297, top-1 accuracy 60.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.583, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.246, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.507406
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 1 / 4
# train part2: batch 0/149, loss 0.326, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.244, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.397165
# val part2: batch 0/298, loss 2.294, top-1 accuracy 40.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.365, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.410, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: loss 0.479802
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 2 / 4
# train part2: batch 0/149, loss 0.665, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.423, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part2: loss 0.243844
# val part2: batch 0/298, loss 0.470, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.289, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.212, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: loss 0.470691
# Checkpoint saved
# part2 Epoch 3 / 4
# train part2: batch 0/149, loss 0.286, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.293, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.212233
# val part2: batch 0/298, loss 1.330, top-1 accuracy 50.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.247, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.896, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: loss 0.424060
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# Best top-1 Accuracy = 86.231

# %% [markdown]
# Expect this code to take around 10 minutes on CPU or 30 seconds on GPU. You should hit 80% accuracy.
